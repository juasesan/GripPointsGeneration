# %%
import cv2 as cv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
import seaborn as sns

# %% [markdown]
# folder = '../Data/test/images'

# %% [markdown]
# for filename in os.listdir(folder):
#     print(filename)

# %% [markdown]
# for filename in os.listdir(folder):
#     img = cv.imread(os.path.join(folder,filename))
#     img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#     ret,thresh = cv.threshold(img,100,255,cv.THRESH_BINARY_INV)
#     img_name = filename.replace("rgb", "msk")
#     cv.imwrite(f"../Data/test/masks/{img_name}", thresh)

# %%
#img = cv.imread('wire.jpg')
img = cv.imread('../Data/sample images/1.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img = cv.resize(img, (400, 400))

# %%
plt.subplots(figsize=(10,8)),plt.imshow(img, 'gray', vmin=0, vmax=255)
plt.show()

# %%
_,thresh2 = cv.threshold(img,100,255,cv.THRESH_BINARY_INV)

# %%
plt.subplots(figsize=(10,8)),plt.imshow(thresh2, 'gray')
plt.show()

# %% [markdown]
# contours, _= cv.findContours(thresh2, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# len(contours)

# %% [markdown]
# contours_clean = []
# for c in contours:
#     area = cv.contourArea(c)
#     if area > 5.0:
#         contours_clean.append(c)

# %% [markdown]
# len(contours_clean)

# %% [markdown]
# cont_index = np.array(areas).argmax()
# wire_cont = contours[cont_index]

# %% [markdown]
# #new_mask = cv.drawContours(thresh2, [wire_cont], -1, color=(255, 255, 255), thickness=cv.FILLED)
# new_mask = cv.drawContours(thresh2, contours_clean, -1, color=(255, 255, 255), thickness=cv.FILLED)

# %% [markdown]
# plt.subplots(figsize=(10,8)),plt.imshow(new_mask, 'gray')
# plt.show()

# %%
points = np.transpose(np.nonzero(thresh2))

# %%
points
# Out:
# array([[ 43, 139],
#        [ 43, 140],
#        [ 43, 141],
#        ...,
#        [339, 196],
#        [343, 198],
#        [344, 201]], dtype=int64)

# %%
knn_graph = kneighbors_graph(points, 30, include_self=False)

# %%
clustering = AgglomerativeClustering(n_clusters=30, linkage="ward", connectivity=knn_graph)

# %%
clustering.fit(points)
# Out:
# AgglomerativeClustering(connectivity=<9241x9241 sparse matrix of type '<class 'numpy.float64'>'
# 	with 277230 stored elements in Compressed Sparse Row format>,
#                         n_clusters=30)

# %%
clustering.labels_
# Out:
# array([ 1,  1,  1, ..., 22, 22, 22], dtype=int64)

# %%
df = pd.DataFrame(points)
df['cluster'] = clustering.labels_
df.columns = ['Y', 'X', 'clusters']
df['Y'] = df['Y'] * (-1)

# %%
df['clusters'].unique()
# Out:
# array([ 1,  3, 25,  5,  6, 16, 15, 26,  2, 11, 23, 13,  8, 10, 19,  0, 12,
#        17, 27, 29,  7, 20, 24, 21,  9, 14,  4, 28, 18, 22], dtype=int64)

# %%
fig,ax = plt.subplots(figsize=(15,12))
sns.scatterplot(data=df, x="X", y='Y', hue="clusters", ax=ax)
_=ax.set_xlim(0,400)
_=ax.set_ylim(-400,0)

# %%
dfg = df.groupby('clusters').agg({'X':[np.mean], 'Y':[np.mean]}).reset_index()
dfg.columns = ['cluster', 'X_cent', 'Y_cent']

# %%
dfg
# Out:
#     cluster      X_cent      Y_cent
# 0         0  242.350649 -205.121212
# 1         1  134.670330  -71.705128
# 2         2  188.664622 -149.458078
# 3         3  173.718412  -78.469314
# 4         4  174.173028 -292.256997
# 5         5  100.881834 -106.846561
# 6         6  227.841849 -122.046229
# 7         7   94.526582 -259.156962
# 8         8  285.254335 -173.872832
# 9         9  235.912393 -272.029915
# 10       10  309.454780 -186.524548
# 11       11  307.078947 -151.864662
# 12       12   81.057143 -224.048571
# 13       13   80.403101 -159.065891
# 14       14  208.194946 -291.530686
# 15       15  290.474453 -133.861314
# 16       16  265.653509 -117.767544
# 17       17  294.938776 -218.275510
# 18       18  165.211604 -319.494881
# 19       19   76.500000 -189.764151
# 20       20  261.372694 -255.107011
# 21       21  119.634656 -274.286013
# 22       22  196.691429 -318.314286
# 23       23  153.422680 -158.443299
# 24       24  142.215247 -280.044843
# 25       25  102.125874  -78.902098
# 26       26   86.323404 -135.110638
# 27       27  280.061947 -239.314159
# 28       28  138.851240 -309.107438
# 29       29   64.558824 -246.941176

# %%
fig,ax = plt.subplots(figsize=(15,12))
sns.scatterplot(data=dfg, x="X_cent", y='Y_cent', ax=ax)
#_=ax.set_xlim(0,400)
#_=ax.set_ylim(-400,0)
plt.xlim(0, 400)
plt.ylim(-400, 0)
plt.axis('off')
ax.imshow(thresh2, extent=[0, 400, -400, 0], aspect='auto', alpha=0.5)
plt.savefig('../Data/sample results/1.jpg')
